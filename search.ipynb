# %%
from pymongo import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://mrraja9789_db_user:F455a250eb@cluster0.wkgrmtg.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# SSL handshake failed: ac-fn8r8ym-shard-00-02.wkgrmtg.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000),SSL handshake failed: ac-fn8r8ym-shard-00-01.wkgrmtg.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000),SSL handshake failed: ac-fn8r8ym-shard-00-00.wkgrmtg.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000), Timeout: 30s, Topology Description: <TopologyDescription id: 6a211b4155ed13f233879e8f, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-fn8r8ym-shard-00-00.wkgrmtg.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-fn8r8ym-shard-00-00.wkgrmtg.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1000)')>, <ServerDescription ('ac-fn8r8ym-shard-00-01.wkgrmtg.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake fail
# ...

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("networksecurity.db")

df = pd.read_sql("SELECT COUNT(*) AS rows FROM NetworkData", conn)
print(df)

df_head = pd.read_sql("SELECT * FROM NetworkData LIMIT 5", conn)
print(df_head)
# Out:
#     rows
# 0  10000
#    id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0   1        3               1          5         72        0
# 1   2        3               1          3        144        0
# 2   3        3               1          2         58        0
# 3   4        3               1          6         79        1
# 4   5        3               0          4         46        0
#
#    NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                  0         0            0              0  ...
# 1                  0         0            0              2  ...
# 2                  0         0            0              0  ...
# 3                  0         0            0              0  ...
# 4                  0         0            0              0  ...
#
#    IframeOrFrame  MissingTitle  ImagesOnlyInForm  SubdomainLevelRT  \
# 0              0             0                 1                 1
# ...

# %%
1+1
# Out:
# 2

# %%
from networksecurity.components.data_ingestion import DataIngestion
from networksecurity.components.data_validation import DataValidation
from networksecurity.entity.config_entity import DataIngestionConfig, DataValidationConfig
from networksecurity.entity.artifact_entity import DataIngestionArtifact
from networksecurity.entity.config_entity import DataIngestionConfig
from networksecurity.entity.config_entity import TrainingPipelineConfig
from networksecurity import logger
from networksecurity.exceptions.exception import NetworkSecurityException
import sys

# %%
try:
    # 1. Setup config objects
    training_pipeline_config = TrainingPipelineConfig()
    data_ingestion_config = DataIngestionConfig(training_pipeline_config)
    
    # 2. Initialize the component
    data_ingestion = DataIngestion(data_ingestion_config)
    
    logger.info("Initiating the data ingestion process")
    
    # 3. Call the correct method (initiate_data_ingestion) 
    # Not data_ingestion_config()
    data_ingestion_artifact = data_ingestion.initiate_data_ingestion()
    
    # 4. Print the result
    print(data_ingestion_artifact)

except Exception as e:
    raise NetworkSecurityException(e, sys)
# Out:
# [2026-06-06 11:21:18,276: INFO: networksecurity: 3850222068: Initiating the data ingestion process]
# [2026-06-06 11:21:18,279: INFO: networksecurity: data_ingestion: Initiating Data Ingestion component]
# [2026-06-06 11:21:18,281: INFO: networksecurity: data_ingestion: Extracting data from SQLite database]
# [2026-06-06 11:21:18,820: INFO: networksecurity: data_ingestion: Data shape from DB: (10000, 50)]
# [2026-06-06 11:21:18,840: INFO: networksecurity: data_ingestion: Saving raw data to: artifacts\06_06_2026_11_21_18\data_ingestion\feature_store\Phishing_Legitimate_full.csv]
# [2026-06-06 11:21:19,014: INFO: networksecurity: data_ingestion: performed train test split on dataframe]
# [2026-06-06 11:21:19,014: INFO: networksecurity: data_ingestion: Exporting train and test file path]
# DataIngestionArtifact(trained_file_path='artifacts\\06_06_2026_11_21_18\\data_ingestion\\ingested\\train.csv', test_file_path='artifacts\\06_06_2026_11_21_18\\data_ingestion\\ingested\\test.csv')

# %%
data_validation_config = DataValidationConfig(training_pipeline_config)
data_validation = DataValidation(data_ingestion_artifact,data_validation_config)

data_validation_artifact = data_validation.initiate_data_validation()
# Out:
# [2026-06-06 11:21:21,528: INFO: networksecurity: main_utils: YAML file loaded successfully: data_schema\schema.yaml]
# [2026-06-06 11:21:21,834: INFO: networksecurity: data_validation: Schema columns count: 49]
# [2026-06-06 11:21:21,835: INFO: networksecurity: data_validation: Dataframe columns count: 49]
# [2026-06-06 11:21:21,837: INFO: networksecurity: data_validation: Column validation successful.]
# [2026-06-06 11:21:21,839: INFO: networksecurity: data_validation: Schema columns count: 49]
# [2026-06-06 11:21:21,839: INFO: networksecurity: data_validation: Dataframe columns count: 49]
# [2026-06-06 11:21:21,845: INFO: networksecurity: data_validation: Column validation successful.]
# [2026-06-06 11:21:22,499: INFO: networksecurity: main_utils: Successfully created YAML file at: artifacts\06_06_2026_11_21_18\data_validation\drift_report\report.yaml]
# ...

# %%
import pandas as pd
df = pd.read_csv("Network_Data/Phishing_Legitimate_full.csv")
df.head()
# Out:
#    id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0   1        3               1          5         72        0
# 1   2        3               1          3        144        0
# 2   3        3               1          2         58        0
# 3   4        3               1          6         79        1
# 4   5        3               0          4         46        0
#
#    NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                  0         0            0              0  ...
# 1                  0         0            0              2  ...
# 2                  0         0            0              0  ...
# 3                  0         0            0              0  ...
# 4                  0         0            0              0  ...
#
#    IframeOrFrame  MissingTitle  ImagesOnlyInForm  SubdomainLevelRT  \
# 0              0             0                 1                 1
# 1              0             0                 0                 1
# ...

# %%
df['CLASS_LABEL'].unique()
# Out:
# array([1, 0])
